# %% [markdown]
# <a href="https://colab.research.google.com/github/trinayasri/new/blob/main/RNN_for_IMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import imdb
from keras.preprocessing import sequence

# %%
max_features = 10000
maxlen = 500
batch_size = 32

# %%
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words = max_features)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print(len(x_train),'train sequences')
print(len(x_test),'test sequences')
# Out:
# 25000 train sequences
# 25000 test sequences

# %%
print ('pad sequences(sample x time)')
# Out:
# pad sequences(sample x time)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
x_train = sequence.pad_sequences(x_train,maxlen = maxlen)
x_test = sequence.pad_sequences(x_test,maxlen = maxlen)
print('x_train shape:',x_train.shape)
print('x_test shape:',x_test.shape)
# Out:
# x_train shape: (25000, 500)
# x_test shape: (25000, 500)

# %%
from keras.layers import Dense, Embedding, SimpleRNN
from keras.models import Sequential
model = Sequential()
model.add(Embedding(10000,32))
model.add(SimpleRNN(32))
model.add(Dense(1,activation = 'sigmoid'))

# %%
model.compile(optimizer = 'rmsprop',loss = 'binary_crossentropy',metrics = ['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs = 10,batch_size = 128,validation_split = 0.2)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 32s 186ms/step - accuracy: 0.5762 - loss: 0.6695 - val_accuracy: 0.7658 - val_loss: 0.5196
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 29s 186ms/step - accuracy: 0.8072 - loss: 0.4395 - val_accuracy: 0.7872 - val_loss: 0.4766
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 190ms/step - accuracy: 0.8573 - loss: 0.3491 - val_accuracy: 0.7342 - val_loss: 0.5405
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 40s 184ms/step - accuracy: 0.8811 - loss: 0.2934 - val_accuracy: 0.8022 - val_loss: 0.4598
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 186ms/step - accuracy: 0.9163 - loss: 0.2226 - val_accuracy: 0.7998 - val_loss: 0.4539
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 29s 185ms/step - accuracy: 0.9424 - loss: 0.1635 - val_accuracy: 0.8016 - val_loss: 0.4774
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 183ms/step - accuracy: 0.9597 - loss: 0.1207 - val_accuracy: 0.8412 - val_loss: 0.4760
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 29s 181ms/step - accuracy: 0.9767 - loss: 0.0750 - val_accuracy: 0.8302 - val_loss: 0.4982
# Epoch 9/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 182ms/step - accuracy: 0.9854 - loss: 0.0495 - val_accuracy: 0.8246 - val_loss: 0.5682
# Epoch 10/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 40s 177ms/step - accuracy: 0.9921 - loss: 0.0297 - val_accuracy: 0.8328 - val_loss: 0.5974

# %%
import matplotlib.pyplot as plt
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(accuracy)+1)
plt.plot(epochs , accuracy , 'bo', label = 'training accuracy')
plt.plot(epochs,val_accuracy,'b' ,label = 'validation accuracy')
plt.title("training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs , loss , 'bo', label = 'training loss')
plt.plot(epochs,val_loss,'b' ,label = 'validation loss')
plt.title("training and validation loss")
plt.legend()
plt.figure()

# %%
# LSTM
from keras.layers import Dense
from keras.layers import LSTM
model = Sequential()
model.add(Embedding(10000,32))
model.add(LSTM(32))
model.add(Dense(1,activation = 'sigmoid'))

# %%
model.compile(optimizer = 'rmsprop',loss = 'binary_crossentropy',metrics = ['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs = 10,batch_size = 128,validation_split = 0.2)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 53s 316ms/step - accuracy: 0.6100 - loss: 0.6468 - val_accuracy: 0.8274 - val_loss: 0.4290
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 81s 309ms/step - accuracy: 0.8255 - loss: 0.4058 - val_accuracy: 0.8662 - val_loss: 0.3228
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 50s 321ms/step - accuracy: 0.8657 - loss: 0.3255 - val_accuracy: 0.8580 - val_loss: 0.3331
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 81s 316ms/step - accuracy: 0.8847 - loss: 0.2929 - val_accuracy: 0.8098 - val_loss: 0.4416
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 83s 320ms/step - accuracy: 0.8949 - loss: 0.2662 - val_accuracy: 0.8084 - val_loss: 0.4523
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 82s 323ms/step - accuracy: 0.9040 - loss: 0.2448 - val_accuracy: 0.8478 - val_loss: 0.4955
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 82s 324ms/step - accuracy: 0.9148 - loss: 0.2263 - val_accuracy: 0.8618 - val_loss: 0.3245
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 50s 317ms/step - accuracy: 0.9212 - loss: 0.2052 - val_accuracy: 0.8808 - val_loss: 0.3069
# Epoch 9/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 82s 320ms/step - accuracy: 0.9281 - loss: 0.1985 - val_accuracy: 0.8608 - val_loss: 0.3126
# Epoch 10/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 50s 321ms/step - accuracy: 0.9328 - loss: 0.1859 - val_accuracy: 0.8688 - val_loss: 0.3113

# %%
import matplotlib.pyplot as plt
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(accuracy)+1)
plt.plot(epochs , accuracy , 'bo', label = 'training accuracy')
plt.plot(epochs,val_accuracy,'b' ,label = 'validation accuracy')
plt.title("training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs , loss , 'bo', label = 'training loss')
plt.plot(epochs,val_loss,'b' ,label = 'validation loss')
plt.title("training and validation loss")
plt.legend()
plt.figure()
